# %% [markdown]
# <a href="https://colab.research.google.com/github/ajmainrahman/Supervised-Machine-Learning-ProblemTypes-Tasks-UseCases/blob/main/Electric_Power_Load_History.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import kagglehub
path = kagglehub.dataset_download("ashfakyeafi/pbd-load-history")
# Out:
# Using Colab cache for faster access to the 'pbd-load-history' dataset.

# %%
import glob

# The path returned by kagglehub.dataset_download might be a root that contains
# a subdirectory with the actual data.
# Let's find all CSV files under 'path' recursively.
csv_files = glob.glob(os.path.join(path, '**', '*.csv'), recursive=True)

if not csv_files:
    raise FileNotFoundError(f"No CSV files found in the downloaded dataset at {path}")

# Assuming there's only one CSV file or we want the first one found
file_to_read = csv_files[0]
print(f"Found CSV file: {file_to_read}")

df = pd.read_csv(file_to_read)
display(df.head())
# Out:
# Found CSV file: /kaggle/input/pbd-load-history/PDB_Load_History.csv
#        date  year  month  day  weekday  hour   demand  temperature
# 0  3/1/2003  2003      3    1        7     1  12863.0           29
# 1  3/1/2003  2003      3    1        7     2  12389.0           28
# 2  3/1/2003  2003      3    1        7     3  12155.0           29
# 3  3/1/2003  2003      3    1        7     4  12072.0           27
# 4  3/1/2003  2003      3    1        7     5  12160.0           29

# %%
import os
print(os.listdir(path))
# Out:
# ['PDB_Load_History.csv']

# %%
df.shape
# Out:
# (103776, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103776 entries, 0 to 103775
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   date         103776 non-null  object
#  1   year         103776 non-null  int64
#  2   month        103776 non-null  int64
#  3   day          103776 non-null  int64
#  4   weekday      103776 non-null  int64
#  5   hour         103776 non-null  int64
#  6   demand       103776 non-null  float64
#  7   temperature  103776 non-null  int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 6.3+ MB

# %%
df.isnull().sum()
# Out:
# date           0
# year           0
# month          0
# day            0
# weekday        0
# hour           0
# demand         0
# temperature    0
# dtype: int64

# %%
df.describe()
# Out:
#                 year          month            day        weekday  \
# count  103776.000000  103776.000000  103776.000000  103776.000000
# mean     2008.574699       6.591813      15.735661       3.999306
# std         3.414726       3.420534       8.802989       2.000183
# min      2003.000000       1.000000       1.000000       1.000000
# 25%      2006.000000       4.000000       8.000000       2.000000
# 50%      2009.000000       7.000000      16.000000       4.000000
# 75%      2012.000000      10.000000      23.000000       6.000000
# max      2014.000000      12.000000      31.000000       7.000000
#
#                hour         demand    temperature
# count  103776.00000  103776.000000  103776.000000
# mean       12.50000   14674.947493      50.576097
# std         6.92222    2894.544130      18.300454
# min         1.00000    7794.000000      -7.000000
# 25%         6.75000   12514.000000      36.000000
# 50%        12.50000   14773.000000      51.000000
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
plt.figure(figsize=(15, 7))
sns.lineplot(x='date', y='demand', data=df)
plt.title('Demand Over Time')
plt.xlabel('Date')
plt.ylabel('Demand')
plt.grid(True)
plt.show()
